# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

data = pd.read_csv(r'D:\RW\RW_Exam\Data_Preprocecing\data\students_employees.csv')
print(data.head())
print(data.columns)
print(data.shape)
print(data[data['Marks']>80].to_csv(r'D:\RW\RW_Exam\Data_Preprocecing\data\high_marks_students.csv', index=False))
# Out:
#     ID      Name  Age  Marks Department
# 0  101  Priyansh   20   85.0         IT
# 1  102      Riya   24   68.0         HR
# 2  103     Karan   28   92.0    Finance
# 3  104      Neha   26   75.0  Marketing
# 4  105     Rahul   23   55.0         IT
# Index(['ID', 'Name', 'Age', 'Marks', 'Department'], dtype='object')
# (12, 5)
# None

# %%
json_data = pd.read_json(r'D:\RW\RW_Exam\Data_Preprocecing\data\employees.json')
print(json_data.head())
json_data.head().to_json(r'D:\RW\RW_Exam\Data_Preprocecing\data\employees_output.json', orient='records', lines=True)
# Out:
#     id      name department
# 0  101  Priyansh         IT
# 1  102      Riya         HR
# 2  103     Karan    Finance
# 3  104      Neha  Marketing
# 4  105     Rahul         IT

# %%
print(data.head(10))
print(data.columns)
print(data.shape)
print(data[data['Age']>25])
# Out:
#     ID      Name  Age  Marks Department
# 0  101  Priyansh   20   85.0         IT
# 1  102      Riya   24   68.0         HR
# 2  103     Karan   28   92.0    Finance
# 3  104      Neha   26   75.0  Marketing
# 4  105     Rahul   23   55.0         IT
# 5  106    Anjali   30   88.0         HR
# 6  107     Vivek   27   72.0    Finance
# 7  108     Pooja   22    NaN  Marketing
# 8  109      Amit   29   90.0         IT
# 9  110     Sneha   26   75.0         HR
# Index(['ID', 'Name', 'Age', 'Marks', 'Department'], dtype='object')
# (12, 5)
#      ID    Name  Age  Marks Department
# 2   103   Karan   28   92.0    Finance
# 3   104    Neha   26   75.0  Marketing
# 5   106  Anjali   30   88.0         HR
# 6   107   Vivek   27   72.0    Finance
# 8   109    Amit   29   90.0         IT
# 9   110   Sneha   26   75.0         HR
# 11  112   Meera   31    NaN    Finance

# %%
print(data.info())
print(data.describe())
data['Marks']=data['Marks'].fillna(data['Marks'].mean())
print(data.duplicated().sum())
data["Marks_Normalized"] = MinMaxScaler().fit_transform(data[["Marks"]])
print(data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                12 non-null     int64
#  1   Name              12 non-null     object
#  2   Age               12 non-null     int64
#  3   Marks             12 non-null     float64
#  4   Department        12 non-null     object
#  5   Marks_Normalized  12 non-null     float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 708.0+ bytes
# None
#                ID        Age      Marks  Marks_Normalized
# count   12.000000  12.000000  12.000000         12.000000
# mean   106.500000  25.750000  75.500000          0.554054
# std      3.605551   3.414541  12.204694          0.329857
# min    101.000000  20.000000  55.000000          0.000000
# 25%    103.750000  23.000000  71.000000          0.432432
# 50%    106.500000  26.000000  75.250000          0.547297
# ...
