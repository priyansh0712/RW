# %% [markdown]
# # Part A - Theoretical Foundation

# %% [markdown]
# 1. What is Statistical Distributions?
# - Statistical distributions are mathematical functions that describe the probabilities of different outcomes in a random experiment. They provide a way to model and analyze the variability and uncertainty in data, allowing us to make predictions and draw conclusions based on observed patterns.

# %% [markdown]
# 2. What is a Q-Q Plot and why is it used?
# - A Q-Q (Quantile-Quantile) plot is a graphical tool used to compare the distribution of a dataset to a theoretical distribution, such as the normal distribution. It plots the quantiles of the dataset against the quantiles of the theoretical distribution. If the points in the Q-Q plot fall approximately along a straight line, it suggests that the data follows the theoretical distribution. Q-Q plots are commonly used to assess normality and identify deviations from expected distributions.

# %% [markdown]
# 3. Difference between Discrete and Continuous Distributions.
# - Discrete distributions describe outcomes that can take on a finite or countable number of values, such as the number of heads in a series of coin flips. Continuous distributions, on the other hand, describe outcomes that can take on an infinite number of values within a given range, such as the height of individuals in a population. Discrete distributions are often represented by probability mass functions (PMFs), while continuous distributions are represented by probability density functions (PDFs).

# %% [markdown]
# 4. What is Bernoulli Distribution?
# - The Bernoulli distribution is a discrete probability distribution that describes the outcomes of a single binary experiment, which can result in one of two possible outcomes: success (usually coded as 1) or failure (usually coded as 0). The distribution is characterized by a single parameter, p, which represents the probability of success. The probability mass function (PMF) of the Bernoulli distribution is given by:
#
#   P(X = 1) = p
#   P(X = 0) = 1 - p
#
#   where X is the random variable representing the outcome of the experiment. The Bernoulli distribution is often used to model situations where there are only two possible outcomes, such as flipping a coin or answering a yes/no question.

# %% [markdown]
# 5. What is Binomial Distribution?
# - The Binomial distribution is a discrete probability distribution that describes the number of successes in a fixed number of independent Bernoulli trials, each with the same probability of success. It is characterized by two parameters: n, the number of trials, and p, the probability of success on each trial. The probability mass function (PMF) of the Binomial distribution is given by:
#
#   P(X = k) = C(n, k) * p^k * (1 - p)^(n - k)
#
#   where X is the random variable representing the number of successes, k is the number of successes we want to find the probability for, and C(n, k) is the binomial coefficient representing the number of ways to choose k successes from n trials. The Binomial distribution is commonly used in scenarios such as quality control, survey sampling, and any situation where there are a fixed number of independent trials with two possible outcomes.

# %% [markdown]
# 6. Explain Log-Normal Distribution.
# - The Log-Normal distribution is a continuous probability distribution of a random variable whose logarithm is normally distributed. In other words, if a random variable X follows a Log-Normal distribution, then Y = ln(X) follows a Normal distribution. The Log-Normal distribution is characterized by two parameters: μ (the mean of the logarithm of the variable) and σ (the standard deviation of the logarithm of the variable).

# %% [markdown]
# 7. Explain Power Law Distribution.
# - The Power Law distribution is a type of probability distribution that follows a specific mathematical relationship, where the probability of an event decreases polynomially with the size of the event. It is characterized by the formula:
#
#   P(X = x) ∝ x^(-α)
#
#   where α is a positive constant known as the exponent or scaling parameter. Power Law distributions are often observed in natural and social phenomena, such as the distribution of wealth, city sizes, and earthquake magnitudes. They are notable for their "heavy tails," meaning that extreme events have a non-negligible probability of occurring.

# %% [markdown]
# 8. What is Box-Cox Transform?
# - The Box-Cox transform is a family of power transformations that are used to stabilize variance and make data more normally distributed. It is defined by the formula:
#
#   y(λ) = (y^λ - 1) / λ, for λ ≠ 0
#   y(λ) = log(y), for λ = 0
#
#   where y is the original data, y(λ) is the transformed data, and λ is the transformation parameter. The Box-Cox transform can be applied to positive-valued data, and the optimal value of λ can be estimated using maximum likelihood estimation. This transformation is particularly useful in regression analysis and other statistical modeling techniques where normality assumptions are important.

# %% [markdown]
# 9. Explain Poisson Distribution with an example.
# - The Poisson distribution is a discrete probability distribution that describes the number of events occurring within a fixed interval of time or space, given that these events occur with a known constant mean rate and independently of the time since the last event. It is characterized by a single parameter, λ (lambda), which represents the average number of events in the interval. The probability mass function (PMF) of the Poisson distribution is given by:
#
#   P(X = k) = (λ^k * e^(-λ)) / k!
#
#   where X is the random variable representing the number of events, k is the number of events we want to find the probability for, and e is Euler's number (approximately 2.71828).
#
#   Example: Suppose a call center receives an average of 5 calls per hour. The number of calls received in an hour can be modeled using a Poisson distribution with λ = 5. The probability of receiving exactly 3 calls in an hour can be calculated as follows:
#
#   P(X = 3) = (5^3 * e^(-5)) / 3! ≈ 0.1404
#
#   This means there is approximately a 14.04% chance of receiving exactly 3 calls in an hour.

# %% [markdown]
# 10. What is Z-score Probability?
# - The Z-score probability refers to the probability associated with a specific Z-score in a standard normal distribution. A Z-score represents the number of standard deviations a data point is from the mean of the distribution. The Z-score can be calculated using the formula:
#
#   Z = (X - μ) / σ
#
#   where X is the value of the data point, μ is the mean of the distribution, and σ is the standard deviation.
#
#   Once the Z-score is calculated, we can use standard normal distribution tables or statistical software to find the probability corresponding to that Z-score. This probability indicates how likely it is to observe a value less than or equal to the given data point in a standard normal distribution.
#
#   For example, if we have a Z-score of 1.5, we can look up this value in a Z-table or use software to find that the probability of observing a value less than or equal to this Z-score is approximately 0.9332, meaning there is a 93.32% chance of observing a value below this point in a standard normal distribution.

# %% [markdown]
# 11. Differentiate Probability Density Function (PDF) and Cumulative Distribution Function (CDF).
# - The Probability Density Function (PDF) and Cumulative Distribution Function (CDF) are both used to describe the distribution of continuous random variables, but they serve different purposes:
#
#   - Probability Density Function (PDF): The PDF describes the likelihood of a random variable taking on a specific value. It is a function that defines the relative likelihood of different outcomes in a continuous distribution. The area under the PDF curve over an interval represents the probability that the random variable falls within that interval. The PDF itself does not give probabilities directly; instead, it must be integrated over an interval to obtain probabilities.
#
#   - Cumulative Distribution Function (CDF): The CDF describes the probability that a random variable takes on a value less than or equal to a specific value. It is obtained by integrating the PDF from negative infinity to the specified value. The CDF is a non-decreasing function that ranges from 0 to 1, and it provides a complete description of the distribution of the random variable.
#
#   In summary, the PDF gives information about the density of probabilities at specific points, while the CDF provides cumulative probabilities up to a certain point.

# %% [markdown]
# # Part B - Data Analysis & Testing Tasks:

# %%
import pandas as pd

data = pd.read_csv('data.csv')
data.head()
# Out:
#                          transaction_id customer_id  transaction_amount  \
# 0  e98aa092-3770-4fdb-9502-5b5a6a244811    CUST2824             3821.34
# 1  11ba6918-dba0-41e5-96cf-f5a7b95f0103    CUST1409             2781.84
# 2  82b7654b-6eb7-4579-89a0-1a9edec0a7bb    CUST5506             4120.97
# 3  f7166574-f400-4d53-b526-0b11f6619ddf    CUST5012             6383.78
# 4  8632fe26-b507-4068-9c68-1b2fa04fecb3    CUST4657             2651.61
#
#   transaction_date  transaction_count region transaction_status
# 0       2023-01-26                  3  North               Fail
# 1       2023-01-28                  0   East               Fail
# 2       2023-01-28                  0  South               Fail
# 3       2023-01-18                  2  South            Success
# 4       2023-01-04                  4  North            Success

# %% [markdown]
# Perform the following using Python (NumPy, Pandas, SciPy, Statsmodels, Matplotlib, Seaborn):

# %%
import numpy as np
from scipy.stats import bernoulli, binom

import matplotlib.pyplot as plt

transaction_occurrence = (data["transaction_status"].str.lower() == "success").astype(int)
p_bernoulli = transaction_occurrence.mean()
bernoulli_fit = bernoulli(p=p_bernoulli)

weekly_counts = (
    pd.to_datetime(data["transaction_date"])
    .dt.to_period("W")
    .value_counts()
    .sort_index()
)

n_binom = int(weekly_counts.max())
p_binom = weekly_counts.mean() / n_binom if n_binom > 0 else 0
binomial_fit = binom(n=n_binom, p=p_binom)

print(f"Bernoulli p: {p_bernoulli:.4f}")
print(f"Binomial n: {n_binom}, p: {p_binom:.4f}")

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Bernoulli
axes[0].bar([0, 1], [1 - p_bernoulli, p_bernoulli], alpha=0.7, label="Fitted Bernoulli")
axes[0].set_xticks([0, 1])
axes[0].set_title("Bernoulli Fit: Transaction Occurrence")
axes[0].set_xlabel("Occurrence")
axes[0].set_ylabel("Probability")
axes[0].legend()

# Binomial
x = np.arange(0, n_binom + 1)
axes[1].bar(x, binomial_fit.pmf(x), alpha=0.7, label="Fitted Binomial")
axes[1].set_title("Binomial Fit: Weekly Transaction Count")
axes[1].set_xlabel("Weekly Count")
axes[1].set_ylabel("Probability")
axes[1].legend()

plt.tight_layout()
plt.show()
# Out:
# Bernoulli p: 0.4455
# Binomial n: 56, p: 0.6548

# %%
#2.Fit the data to Poisson distribution (number of transactions per day).
from matplotlib.pylab import poisson
from scipy.stats import poisson

daily_counts = (pd.to_datetime(data["transaction_date"]).dt.date.value_counts().sort_index())

lambda_poisson = daily_counts.mean()
poisson_fit = poisson(mu=lambda_poisson)

print(f"Poisson lambda: {lambda_poisson:.4f}")
# Out:
# Poisson lambda: 7.0968

# %%
#3. Model transaction amounts using Log-Normal and Power Law distributions.

from scipy.stats import lognorm, pareto
model_data = data["transaction_amount"].dropna()
log_normal_fit = np.log(model_data).mean(), np.log(model_data).std()
print(f"Log-Normal fit: mean={log_normal_fit[0]:.4f}, std={log_normal_fit[1]:.4f}")

power_law_fit = (model_data.min(), model_data.max())
shape_ln, loc_ln, scale_ln = lognorm.fit(model_data, floc=0)
power_shape, power_loc, power_scale = pareto.fit(model_data, floc=0)

log_normal_fit = (np.log(scale_ln), shape_ln)
power_law_fit = (power_shape, power_scale)
print(f"Power Law fit: min={power_law_fit[0]:.4f}, max={power_law_fit[1]:.4f}")
x = np.linspace(model_data.min(), model_data.max(), 500)
plt.figure(figsize=(10, 5))
plt.hist(model_data, bins=30, density=True, alpha=0.4, label="Observed")
plt.plot(x, lognorm.pdf(x, shape_ln, loc_ln, scale_ln), label="Log-Normal")
plt.plot(x, pareto.pdf(x, power_shape, power_loc, power_scale), label="Power Law")
plt.title("Transaction Amount Distribution Fits")
plt.xlabel("Transaction Amount")
plt.ylabel("Density")
plt.legend()
plt.show()
# Out:
# Log-Normal fit: mean=8.0007, std=0.4760
# Power Law fit: min=0.7630, max=804.4200

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

qq_data = model_data.dropna()

fig, ax = plt.subplots(figsize=(6, 6))
stats.probplot(qq_data, dist="norm", plot=ax)
ax.set_title("Q-Q Plot of Transaction Amounts")
ax.set_xlabel("Theoretical Quantiles")
ax.set_ylabel("Sample Quantiles")
plt.tight_layout()
stats.probplot(qq_data, dist="norm")
plt.show()

# %%
# Apply Box-Cox transform to the transaction amounts
bc_data = model_data.dropna().astype(float)

shift = 0
if (bc_data <= 0).any():
    shift = abs(bc_data.min()) + 1
    bc_data = bc_data + shift

boxcox_transformed, boxcox_lambda = stats.boxcox(bc_data)

print(f"Box-Cox lambda: {boxcox_lambda:.4f}")
print(f"Applied shift: {shift:.4f}")

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].hist(model_data.dropna(), bins=30, density=True, alpha=0.7)
axes[0].set_title("Original Transaction Amounts")
axes[0].set_xlabel("Transaction Amount")
axes[0].set_ylabel("Density")

axes[1].hist(boxcox_transformed, bins=30, density=True, alpha=0.7, color="orange")
axes[1].set_title("Box-Cox Transformed Amounts")
axes[1].set_xlabel("Transformed Value")
axes[1].set_ylabel("Density")

plt.tight_layout()
plt.show()
# Out:
# Box-Cox lambda: -0.1808
# Applied shift: 0.0000

# %%
# Z-scores and probability of transactions exceeding ₹5000

mu = model_data.mean()
sigma = model_data.std(ddof=0)  # population std
z_scores = (model_data - mu) / sigma

z_5000 = (5000 - mu) / sigma
prob_gt_5000_norm = stats.norm.sf(z_5000)            # Normal-approx probability
prob_gt_5000_empirical = (model_data > 5000).mean()  # Empirical probability

print(f"Mean={mu:.2f}, Std={sigma:.2f}")
print(f"Z-score for 5000: {z_5000:.4f}")
print(f"P(X>5000) (Normal approx): {prob_gt_5000_norm:.4f}")
print(f"P(X>5000) (Empirical): {prob_gt_5000_empirical:.4f}")
# Out:
# Mean=3365.19, Std=1981.19
# Z-score for 5000: 0.8252
# P(X>5000) (Normal approx): 0.2046
# P(X>5000) (Empirical): 0.1136

# %%
# PDF and CDF for transaction amounts using the fitted Log-Normal model

x_vals = np.linspace(model_data.min(), model_data.max(), 500)
pdf_vals = stats.lognorm.pdf(x_vals, shape_ln, loc=loc_ln, scale=scale_ln)
cdf_vals = stats.lognorm.cdf(x_vals, shape_ln, loc=loc_ln, scale=scale_ln)

sorted_data = np.sort(model_data.values)
ecdf = np.arange(1, len(sorted_data) + 1) / len(sorted_data)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# PDF
axes[0].hist(model_data, bins=30, density=True, alpha=0.35, label="Observed density")
axes[0].plot(x_vals, pdf_vals, color="crimson", linewidth=2, label="Fitted Log-Normal PDF")
axes[0].set_title("PDF of Transaction Amounts")
axes[0].set_xlabel("Transaction Amount")
axes[0].set_ylabel("Density")
axes[0].legend()

# CDF
axes[1].plot(x_vals, cdf_vals, color="navy", linewidth=2, label="Fitted Log-Normal CDF")
axes[1].step(sorted_data, ecdf, where="post", color="gray", alpha=0.7, label="Empirical CDF")
axes[1].set_title("CDF of Transaction Amounts")
axes[1].set_xlabel("Transaction Amount")
axes[1].set_ylabel("Cumulative Probability")
axes[1].legend()

plt.tight_layout()
plt.show()

mode_x = x_vals[np.argmax(pdf_vals)]
median_x = np.median(model_data)

print(f"PDF interpretation: the highest density is around ₹{mode_x:.2f}, so amounts near this value are most common.")
print("CDF interpretation: the curve rises slowly at first and faster in the mid-range, showing a right-skewed distribution.")
print(f"About 50% of transactions are at or below the median amount of ₹{median_x:.2f}.")
print("The upper tail is relatively long, so a small number of large transactions contribute to the extreme right side.")
# Out:
# PDF interpretation: the highest density is around ₹2380.25, so amounts near this value are most common.
# CDF interpretation: the curve rises slowly at first and faster in the mid-range, showing a right-skewed distribution.
# About 50% of transactions are at or below the median amount of ₹3077.72.
# The upper tail is relatively long, so a small number of large transactions contribute to the extreme right side.

# %%
print("Conclusion: The Log-Normal distribution is the best fit for transaction_amount.")
print("Why:")
print("The data is strictly positive and strongly right-skewed.The Q-Q plot shows clear deviation from normality, so a Normal model is weak.The Q-Q plot shows clear deviation from normality, so a Normal model is weak.The fitted Log-Normal curve follows the observed histogram and density shape better than the Power Law fit.The Box-Cox result also supports the idea that a power-type transform is needed to reduce skewness.")
print(" ")
print("Decision-making insight:")
print("The mean is pulled upward by a small number of large transactions, so the median is a better 'typical' value.Large transactions are rare but important, so risk limits, fraud checks, and forecasting should use percentile-based thresholds.Planning should focus on the long right tail, since a few high-value transactions can materially affect revenue and risk.")
# Out:
# Conclusion: The Log-Normal distribution is the best fit for transaction_amount.
# Why:
# The data is strictly positive and strongly right-skewed.The Q-Q plot shows clear deviation from normality, so a Normal model is weak.The Q-Q plot shows clear deviation from normality, so a Normal model is weak.The fitted Log-Normal curve follows the observed histogram and density shape better than the Power Law fit.The Box-Cox result also supports the idea that a power-type transform is needed to reduce skewness.
#
# Decision-making insight:
# The mean is pulled upward by a small number of large transactions, so the median is a better 'typical' value.Large transactions are rare but important, so risk limits, fraud checks, and forecasting should use percentile-based thresholds.Planning should focus on the long right tail, since a few high-value transactions can materially affect revenue and risk.
