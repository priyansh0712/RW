# %% [markdown]
# ## Today's topics
#
# - Central Limit Theorem
# - Chi-Square Test
# - Test Implementation of categorical data

# %% [markdown]
# ---

# %% [markdown]
# # 🔹 Chi-Square Test (Goodness of Fit)
#
# Example:
#
# A company claims that customer preference for 4 flavors is equally distributed.
#
# Observed survey results:
#
# | Flavor | Observed |
# | -------|----------|
# |   A    |    30    |
# |   B    |    25    |
# |   C    |    20    |
# |   D    |    25    |
#
# We test whether preferences are truly equal.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Chi-Square Test (Goodness of Fit)

import numpy as np
from scipy import stats

# -----------------------------
# Step 1: Observed Frequencies
# -----------------------------
observed = np.array([30, 25, 20, 25])

# -----------------------------
# Step 2: Expected Frequencies
# (Equal distribution assumption)
# -----------------------------
total = observed.sum()   # sum(observerd)  or  np.sum(observerd)
k = len(observed)
expected = np.array([total / k] * k)

# -----------------------------
# Step 3: Manual Chi-Square Statistic
# χ² = Σ (O - E)^2 / E
# -----------------------------
chi_square_stat = ((observed - expected) ** 2 / expected).sum()

# -----------------------------
# Step 4: Degrees of Freedom
# df = k - 1
# -----------------------------
df = k - 1

# -----------------------------
# Step 5: Calculate p-value or critical_value
# -----------------------------
alpha = 0.05

p_value = 1 - stats.chi2.cdf(chi_square_stat, df)
critical_value = stats.chi2.ppf(1 - alpha, df)

# -----------------------------
# Step 6: Decision (from p_value or from critical_value)
# -----------------------------

# if p_value < alpha:
#     decision = "Reject H0"
# else:
#     decision = "Fail to Reject H0"

if chi_square_stat > critical_value:
    decision = "Reject H0"
else:
    decision = "Fail to Reject H0"


# -----------------------------
# Final Output
# -----------------------------
print("Observed:", observed)
print("Expected:", expected)
print("\nChi-Square Statistic:", chi_square_stat)
print("Degrees of Freedom:", df)
print("p-value:", p_value)
print("Critical Value:", critical_value)
print("Decision:", decision)
# Out:
# Observed: [30 25 20 25]
# Expected: [25. 25. 25. 25.]
#
# Chi-Square Statistic: 2.0
# Degrees of Freedom: 3
# p-value: 0.5724067044708798
# Critical Value: 7.814727903251179
# Decision: Fail to Reject H0

# %% [markdown]
# # 🔹 Chi-Square Test of Independence
#
# Example:
#
# We want to check:
#
# Is Gender related to Product Purchase?
#
# Observed data:
# |        | Purchased | Not Purchased |
# |--------|-----------|---------------|
# |  Male  |    30     |       20      |
# | Female |    25     |       25      |

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Chi-Square Test of Independence

import numpy as np
from scipy import stats

# -----------------------------
# Step 1: Observed Contingency Table
# -----------------------------
observed = np.array([
    [30, 20],   # Male
    [25, 25]    # Female
])

# -----------------------------
# Step 2: Row Totals, Column Totals, Grand Total
# -----------------------------
row_totals = observed.sum(axis=1)
col_totals = observed.sum(axis=0)
grand_total = observed.sum()

# -----------------------------
# Step 3: Expected Frequencies (Manual)
# E = (Row Total × Column Total) / Grand Total
# -----------------------------
expected = np.outer(row_totals, col_totals) / grand_total

# -----------------------------
# Step 4: Chi-Square Statistic (Manual)
# χ² = Σ (O - E)^2 / E
# -----------------------------
chi_square_stat = ((observed - expected) ** 2 / expected).sum()

# -----------------------------
# Step 5: Degrees of Freedom
# df = (r - 1)(c - 1)
# -----------------------------
r, c = observed.shape
df = (r - 1) * (c - 1)

# -----------------------------
# Step 6: Find p-value and critical_value
# -----------------------------
alpha = 0.05

p_value = 1 - stats.chi2.cdf(chi_square_stat, df)
critical_value = stats.chi2.ppf(1 - alpha, df)

# -----------------------------
# Step 7: Decision
# -----------------------------

# if p_value < alpha:
#     decision = "Reject H0 (Variables are related)"
# else:
#     decision = "Fail to Reject H0 (Variables are independent)"

if chi_square_stat > critical_value:
    decision = "Reject H0 (Variables are related)"
else:
    decision = "Fail to Reject H0 (Variables are independent)"

# -----------------------------
# Final Output
# -----------------------------
print("Observed Table:\n", observed)
print("\nExpected Table:\n", expected)
print("\nChi-Square Statistic:", chi_square_stat)
print("Degrees of Freedom:", df)
print("p-value:", p_value)
print("Critical Value:", critical_value)
print("Decision:", decision)
# Out:
# Observed Table:
#  [[30 20]
#  [25 25]]
#
# Expected Table:
#  [[27.5 22.5]
#  [27.5 22.5]]
#
# Chi-Square Statistic: 1.0101010101010102
# Degrees of Freedom: 1
# p-value: 0.31487864133641974
# Critical Value: 3.841458820694124
# Decision: Fail to Reject H0 (Variables are independent)

# %% [markdown]
# ## 📝 Practice Questions
# 1.	What does the Central Limit Theorem state in simple words?
# 2.	Why is CLT important in inferential statistics?
# 3.	What happens to the sampling distribution when sample size increases?
# 4.	Why is sample size ≥ 30 often recommended?
#
# 5.	When do we use the Chi-Square Test?
# 6.	Difference between:
# - Goodness of Fit test
# - Test of Independence
# 7.	How are degrees of freedom calculated in:
# - Goodness of Fit
# - Independence test?
# 8.	Why is Chi-Square always right-tailed?

# %% [markdown]
# ## 📌 Mini Assignment

# %% [markdown]
# **Question 1: Chi-Square Test (Goodness of Fit)**
#
# 📘 Scenario
#
# A telecom company claims that customer complaints are distributed as:
# | Category | Expected % |
# |----------|------------|
# | Network  |     50%    |
# | Billing  |     30%    |
# | Service  |     20%    |
#
# From 300 complaints, observed counts are:
# | Category |  Observed  |
# |----------|------------|
# | Network  |     120    |
# | Billing  |     110    |
# | Service  |      70    |
#
# Test the claim at α = 0.05.
#
# 📝 Tasks
#
# 1.	State H₀ and H₁.
# 2.	Calculate expected frequencies.
# 3.	Compute Chi-Square statistic manually.
# 4.	Find degrees of freedom.
# 5.	Compute p-value.
# 6.	Find critical Chi-Square value.
# 7.	Make decision using:
# - Method-1 (p-value comparison)
# - Method-2 (critical value comparison)
# 8.	Interpret result in plain English.

# %%
import numpy as np
from scipy import stats

observed = np.array([120,110,70])
alpha = 0.05
expected = np.array([150,90,60])
chi_square_stat = ((observed - expected) ** 2 / expected).sum()
df = len(observed) - 1
p_value = 1 - stats.chi2.cdf(chi_square_stat, df)
critical_value = stats.chi2.ppf(1 - alpha, df)

print("Chi-Square Statistic:", chi_square_stat)
print("Degrees of Freedom:", df)
print("p-value:", p_value)
print("Critical Value:", critical_value)

if chi_square_stat > critical_value:
    decision = "Reject H0"
else:
    decision = "Fail to Reject H0"
print("Decision:", decision)
# Out:
# Chi-Square Statistic: 12.11111111111111
# Degrees of Freedom: 2
# p-value: 0.002344799092590777
# Critical Value: 5.991464547107979
# Decision: Reject H0

# %% [markdown]
# **Question 2: Chi-Square Test of Independence**
#
# 📘 Scenario
#
# A survey checks if Device Type affects Subscription Plan.
#
# |            |  Basic  |  Premium  |
# |------------|---------|-----------|
# |  Android   |    80   |     40    |
# |     iOS    |    60   |     70    |
#
# Test whether subscription plan depends on device type at α = 0.05.
#
# 📝 Tasks
#
# 1.	State H₀ and H₁.
# 2.	Compute expected frequencies.
# 3.	Calculate Chi-Square statistic.
# 4.	Compute degrees of freedom.
# 5.	Find p-value.
# 6.	Compute critical value.
# 7.	Apply BOTH decision methods.
# 8.	Interpret association in business language.

# %%
observed = np.array([[80,40], [60,70]])

row_totals = observed.sum(axis=1)
col_totals = observed.sum(axis=0)
grand_total = observed.sum()

expected = np.outer(row_totals, col_totals) / grand_total
chi_square_stat = ((observed - expected) ** 2 / expected).sum()
r, c = observed.shape
df = (r - 1) * (c - 1)
p_value = 1 - stats.chi2.cdf(chi_square_stat, df)
critical_value = stats.chi2.ppf(1 - alpha, df)
alpha = 0.05
print("Chi-Square Statistic:", chi_square_stat)
print("Degrees of Freedom:", df)
print("p-value:", p_value)
print("Critical Value:", critical_value)

if chi_square_stat > critical_value:
    decision = "Reject H0 (Variables are related)"
else:    
    decision = "Fail to Reject H0 (Variables are independent)"
print("Decision:", decision)
# Out:
# Chi-Square Statistic: 10.65601065601065
# Degrees of Freedom: 1
# p-value: 0.001097137768081513
# Critical Value: 3.841458820694124
# Decision: Reject H0 (Variables are related)

# %%
# generate a non-normal population dataset
import numpy as np
np.random.seed(0)
data = np.random.exponential(scale=1.0, size=1000)
# draw 1000 sample and calculate their means
sample_means = [np.random.choice(data, size=30).mean() for _ in range(1000)]
# plot the distribution of sample means
import matplotlib.pyplot as plt
plt.hist(sample_means, bins=30, density=True, alpha=0.6, color='g')
plt.title('Distribution of Sample Means (n=30)')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.show()
# observe if the shape is approximately normal
print("Sample Means - Mean:", np.mean(sample_means), "Std Dev:", np.std(sample_means))
# Out:
# Sample Means - Mean: 0.9987994536716294 Std Dev: 0.1899182729887847

# %%
# simulate rolling a dice 120 times and record the frequency of each outcome
import numpy as np
np.random.seed(0)
rolls = np.random.randint(1, 7, size=120)
frequencies = np.array([np.sum(rolls == i) for i in range(1, 7)])
# Assume the expected frequancy is equal for all faces(1-6)
expected = np.array([20] * 6)  # 120 rolls / 6 faces
# perform chi-square goodness of fit test
from scipy import stats
chi_square_stat, p_value = stats.chisquare(frequencies, f_exp=expected)
critical_value = stats.chi2.ppf(1 - 0.05, df=5)  # df = number of categories - 1

print("Observed Frequencies:", frequencies)
print("Expected Frequencies:", expected)
print("Chi-Square Statistic:", chi_square_stat)
print("p-value:", p_value)
print("Critical Value:", critical_value)
if chi_square_stat > critical_value:
    decision = "Reject H0 (Dice is not fair)"
else:
    decision = "Fail to Reject H0 (Dice is fair)"
print("Decision:", decision)
# Out:
# Observed Frequencies: [22 20 19 23 19 17]
# Expected Frequencies: [20 20 20 20 20 20]
# Chi-Square Statistic: 1.2
# p-value: 0.9448773650021219
# Critical Value: 11.070497693516351
# Decision: Fail to Reject H0 (Dice is fair)

# %%
# create 2x3 contigancy table gender(Male,female) and genre(Action, Comedy, Drama)
import numpy as np
observed = np.array([[30, 20, 25], [25, 25, 20]])
row_totals = observed.sum(axis=1)
col_totals = observed.sum(axis=0)
grand_total = observed.sum()
expected = np.outer(row_totals, col_totals) / grand_total
chi_square_stat = ((observed - expected) ** 2 / expected).sum()
r, c = observed.shape
df = (r - 1) * (c - 1)
alpha = 0.05
p_value = 1 - stats.chi2.cdf(chi_square_stat, df)
critical_value = stats.chi2.ppf(1 - alpha, df)
print("Observed Table:\n", observed)
print("\nExpected Table:\n", expected)
print("\nChi-Square Statistic:", chi_square_stat)
print("Degrees of Freedom:", df)
print("p-value:", p_value)
print("Critical Value:", critical_value)
if chi_square_stat > critical_value:
    decision = "Reject H0 (Gender and Genre are related)"
else:
    decision = "Fail to Reject H0 (Gender and Genre are independent)"
print("Decision:", decision)
# Out:
# Observed Table:
#  [[30 20 25]
#  [25 25 20]]
#
# Expected Table:
#  [[28.44827586 23.27586207 23.27586207]
#  [26.55172414 21.72413793 21.72413793]]
#
# Chi-Square Statistic: 1.3949013949013949
# Degrees of Freedom: 2
# p-value: 0.49785286498431736
# Critical Value: 5.991464547107979
# Decision: Fail to Reject H0 (Gender and Genre are independent)

# %%
# create a contingency table with Education level (school, graduate, postgraduate) vs Internet usage (Low, Medium, High)
import numpy as np
observed = np.array([[30, 25, 20], [25, 25, 20], [20, 15, 10]])
row_totals = observed.sum(axis=1)
col_totals = observed.sum(axis=0)
grand_total = observed.sum()
expected = np.outer(row_totals, col_totals) / grand_total
chi_square_stat = ((observed - expected) ** 2 / expected).sum()
r, c = observed.shape
df = (r - 1) * (c - 1)
alpha = 0.05
p_value = 1 - stats.chi2.cdf(chi_square_stat, df)
critical_value = stats.chi2.ppf(1 - alpha, df)
print("Observed Table:\n", observed)
print("\nExpected Table:\n", expected)
print("\nChi-Square Statistic:", chi_square_stat)
print("Degrees of Freedom:", df)
print("p-value:", p_value)
print("Critical Value:", critical_value)
if chi_square_stat > critical_value:
    decision = "Reject H0 (Education level and Internet usage are related)"
else:
    decision = "Fail to Reject H0 (Education level and Internet usage are independent)"
print("Decision:", decision)
# Out:
# Observed Table:
#  [[30 25 20]
#  [25 25 20]
#  [20 15 10]]
#
# Expected Table:
#  [[29.60526316 25.65789474 19.73684211]
#  [27.63157895 23.94736842 18.42105263]
#  [17.76315789 15.39473684 11.84210526]]
#
# Chi-Square Statistic: 1.0362230362230365
# Degrees of Freedom: 4
# p-value: 0.9042545485291833
# Critical Value: 9.487729036781154
# Decision: Fail to Reject H0 (Education level and Internet usage are independent)

# %%
# construct aa 3x3 contingency table with Age group(teens,adult,seniors) vs food types(vegetarian, non-vegetarian, mixed)
import numpy as np
observed = np.array([[30, 25, 20], [25, 25, 20], [20, 15, 10]])
row_totals = observed.sum(axis=1)
col_totals = observed.sum(axis=0)
grand_total = observed.sum()
expected = np.outer(row_totals, col_totals) / grand_total
chi_square_stat = ((observed - expected) ** 2 / expected).sum()
r, c = observed.shape
df = (r - 1) * (c - 1)
alpha = 0.05
p_value = 1 - stats.chi2.cdf(chi_square_stat, df)
critical_value = stats.chi2.ppf(1 - alpha, df)
print("Observed Table:\n", observed)
print("\nExpected Table:\n", expected)
print("\nChi-Square Statistic:", chi_square_stat)
print("Degrees of Freedom:", df)
print("p-value:", p_value)
print("Critical Value:", critical_value)
if chi_square_stat > critical_value:
    decision = "Reject H0 (Age group and Food type are related)"
else:
    decision = "Fail to Reject H0 (Age group and Food type are independent)"
print("Decision:", decision)
# Out:
# Observed Table:
#  [[30 25 20]
#  [25 25 20]
#  [20 15 10]]
#
# Expected Table:
#  [[29.60526316 25.65789474 19.73684211]
#  [27.63157895 23.94736842 18.42105263]
#  [17.76315789 15.39473684 11.84210526]]
#
# Chi-Square Statistic: 1.0362230362230365
# Degrees of Freedom: 4
# p-value: 0.9042545485291833
# Critical Value: 9.487729036781154
# Decision: Fail to Reject H0 (Age group and Food type are independent)
